# %%
import sys
import os

print(f"Project Path: {os.getcwd()}")
print(f"Engine Path:  {sys.executable}")

try:
    import sklearn
    print(f"Scikit-Learn: Found (Version {sklearn.__version__})")
except ImportError:
    print("Scikit-Learn: MISSING - Needs 'pip install scikit-learn' in this venv")
# Out:
# Project Path: c:\Users\beall\Documents\Math\Notebooks\ANLY699\notebooks
# Engine Path:  c:\Users\beall\Documents\Math\Notebooks\ANLY699\venv\Scripts\python.exe
# Scikit-Learn: Found (Version 1.8.0)
